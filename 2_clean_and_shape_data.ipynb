# %%
from numpy.ma.core import indices
from scipy import stats
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('features.csv')

# %%
n_rows = df.index  # row length
num_cols = df.select_dtypes(include=['number']).columns   # gives column names
outlier_info = {}

# %%
for col in num_cols:

    z_col = stats.zscore(df[col])
    mask = np.abs(z_col) > 7

    outlier_info[col] = {
        'indices': df[mask].index.tolist(),
        'original_values': df.loc[mask, col].round(2).tolist(),
        'z_scores': z_col[mask].round(2).tolist()
    }

    count = len(outlier_info[col]['indices'])

    print(col)

    if count > 0:
        print(f"\n{count} outliers in {col}:")
        for idx, val, z in zip(outlier_info[col]['indices'],
                                outlier_info[col]['original_values'],
                                outlier_info[col]['z_scores']):
            print(f"  Index {idx}: value={val}, z-score={z}")
# Out:
# area
#
# 5 outliers in area:
#   Index 72: value=161.0, z-score=-9.91
#   Index 272: value=318.0, z-score=-9.81
#   Index 408: value=11.0, z-score=-10.0
#   Index 724: value=2.0, z-score=-10.01
#   Index 1615: value=4.0, z-score=-10.01
# perimeter
#
# 10 outliers in perimeter:
#   Index 72: value=71.66, z-score=-7.82
#   Index 113: value=1306.15, z-score=10.17
#   Index 115: value=1175.75, z-score=8.27
#   Index 186: value=1119.62, z-score=7.46
#   Index 221: value=1427.28, z-score=11.94
#   Index 236: value=1405.25, z-score=11.62
#   Index 272: value=79.9, z-score=-7.7
#   Index 408: value=9.0, z-score=-8.73
#   Index 724: value=0.0, z-score=-8.86
#   Index 1615: value=2.0, z-score=-8.83
# eccentricity
# mean_intensity

# %%
# compile outlier rows
outlier_rows = []

for col in num_cols:
    print(col)
    for key, values in outlier_info[col].items():
        print(key, values)
        if key == "indices":
            outlier_rows.extend(values)

outlier_rows = set(outlier_rows)
print(outlier_rows)
# Out:
# area
# indices [72, 272, 408, 724, 1615]
# original_values [161.0, 318.0, 11.0, 2.0, 4.0]
# z_scores [-9.91, -9.81, -10.0, -10.01, -10.01]
# perimeter
# indices [72, 113, 115, 186, 221, 236, 272, 408, 724, 1615]
# original_values [71.66, 1306.15, 1175.75, 1119.62, 1427.28, 1405.25, 79.9, 9.0, 0.0, 2.0]
# z_scores [-7.82, 10.17, 8.27, 7.46, 11.94, 11.62, -7.7, -8.73, -8.86, -8.83]
# eccentricity
# indices []
# original_values []
# z_scores []
# mean_intensity
# indices []
# original_values []
# z_scores []
# {72, 236, 1615, 272, 113, 115, 724, 408, 186, 221}

# %%
print(df.shape)
# Out:
# (2002, 6)

# %%
df.drop(outlier_rows)
# Out:
#                                        source_image     area   perimeter  \
# 0     C100P61ThinF_IMG_20150918_144104_cell_162.png  16841.0  609.480231
# 1     C100P61ThinF_IMG_20150918_144104_cell_163.png  14517.0  758.918831
# 2     C100P61ThinF_IMG_20150918_144104_cell_164.png  16823.0  634.592929
# 3     C100P61ThinF_IMG_20150918_144104_cell_165.png  14370.0  624.007143
# 4     C100P61ThinF_IMG_20150918_144104_cell_166.png  15565.0  606.793939
# ...                                             ...      ...         ...
# 1997   C114P75ThinF_IMG_20150930_150733_cell_19.png  17708.0  563.195959
# 1998   C114P75ThinF_IMG_20150930_150733_cell_21.png  17702.0  571.130988
# 1999    C114P75ThinF_IMG_20150930_150733_cell_5.png  15377.0  561.273124
# 2000   C114P75ThinF_IMG_20150930_150733_cell_62.png  16895.0  572.338095
# 2001    C114P75ThinF_IMG_20150930_150733_cell_7.png  15351.0  560.994949
#
#       eccentricity  mean_intensity        label
# 0         0.407135        0.502156  parasitized
# 1         0.715454        0.423047  parasitized
# 2         0.354411        0.503058  parasitized
# 3         0.590075        0.434115  parasitized
# 4         0.683484        0.474308  parasitized
# ...            ...             ...          ...
# 1997      0.314891        0.461355   uninfected
# 1998      0.331042        0.482025   uninfected
# 1999      0.737392        0.397110   uninfected
# 2000      0.342895        0.460976   uninfected
# 2001      0.713589        0.403038   uninfected
#
# [1992 rows x 6 columns]
